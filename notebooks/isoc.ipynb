# %%
from starcat import Isoc, Parsec
from starcat.tests import isoc_test

# %%
# use Parsec model
p = Parsec()
i = Isoc(p)

# get one isoc from Parsec for gaiaDR2
logage, mh = 7.89, 0.032
logage_step, mh_step = 0.01, 0.01
isoc = i.get_isoc(
    photsyn="gaiaDR2", logage=logage, mh=mh, logage_step=logage_step, mh_step=mh_step
)

# %%
isoc
# Out:
#     phase      Mini    Gmag  G_BPmag  G_RPmag
# 0     PMS  0.090000  13.420   16.263   12.067
# 1     PMS  0.091098  13.398   16.242   12.045
# 2     PMS  0.099352  13.234   16.079   11.881
# 3     PMS  0.100000  13.221   16.066   11.868
# 4     PMS  0.108760  13.043   15.847   11.694
# ..    ...       ...     ...      ...      ...
# 269  EAGB  5.915961  -4.003   -1.155   -5.361
# 270  EAGB  5.915965  -3.979   -1.100   -5.340
# 271  EAGB  5.915970  -3.906   -0.951   -5.279
# 272  EAGB  5.915982  -3.726   -0.591   -5.126
# 273  EAGB  5.916010  -3.511   -0.170   -4.942
#
# [274 rows x 5 columns]

# %%
isoc_test.draw_isoc(isoc, "parsec", "gaiaDR2")
